# %%
#Reload changes -> always run this
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Homework 7
# #### Ron Cordell, Ted Dunmire, Filip Krunic
#
# *In this assignment, you will explore networks and develop MRJob code for finding shortest path graph distances. To build up to large datasets, you will develop your code on some very simple toy networks. Afte rthis, you will take your developed code and modify it, applying it to two larger datasets (performing EDA along the way).*
#
# -----
#
# ### Question 7.0
#
# *Write MRJob classes to find the shortest path graph distances as described in the lectures. In addition to finding the distances, your code should also output a distance-minimizing path between the source and target. Work locally for this part of the assignment, and use both of the undirected and directed toy networks.*
#
# *Make sure your output is correct!*
#
# #### Solution:
#
# To accomplish this task, we write two separate MRJob classes. The first of these, `initGraphJob` initializes the graph and assigns a starter node. The second, `ShortestPathJob` actually finds the shortest path between the start and end nodes of choice.
#
# ##### Driver
#
# Below is the driver file for the job. This iterates over both of the jobs specified above, and prints the shortest path output for both toy datasets.

# %%
# %%writefile driver.py

#Driver for iterations
import os
from init_data import initGraphJob
from shortest_path import ShortestPathJob

def findShortestPath(filename, startNode, endNode):
    
    mr_job_init = initGraphJob(args = [filename, '--startNode', startNode]) #insert text file here to change 

    with open('working-graph.txt', 'w+') as myfile:
        
        with mr_job_init.make_runner() as runner:
            runner.run()
            
            for line in runner.stream_output():
                myfile.write(line)


    while True:
        with open('newFile.txt', 'w+') as myfile:
            mr_job = ShortestPathJob(args = ['working-graph.txt'])
            
            with mr_job.make_runner() as runner:
                runner.run()
                
                for line in runner.stream_output():
                    output = mr_job.parse_output_line(line)
                    myfile.write(line)
                
                    if output[0] == endNode and output[1][2] == "V":
                        return (output[1][3], output[1][1]) 
                        break
            
        os.rename('newFile.txt', 'working-graph.txt')

print 'Shortest path in undirected Graph:'
results = findShortestPath('undirected_toy.txt', '1', '4')
print 'Path: ' + str(results[0]) + ', with distance ' + str(results[1])

print 'Shortest path in directed Graph:'
results = findShortestPath('directed_toy.txt', '1', '5')
print 'Path: ' + str(results[0]) + ', with distance ' + str(results[1])

# Clean 
try: 
    os.remove('newFile.txt')
    os.remove('working-graph.txt')

except: 
    print 'Unable to clean files.'
# Out:
# Overwriting driver.py

# %% [markdown]
# ##### Initialize
#
# Below is the class for the initialization of the graph search. The main purpose of this class is to read in the graph data and output the node, along with its neighbors and graph structure. This lets us 'hold' the graph in the stream for the `ShortestPathJob` to execute on.

# %%
# %%writefile init_data.py

from sys import maxint
from mrjob.job import MRJob
from mrjob.step import MRStep

class initGraphJob(MRJob):
    
    def configure_options(self):
        super(initGraphJob, self).configure_options()
        self.add_passthrough_option('--startNode', default = '1')
    
    def mapper(self, _, node):
        nodeID, links = node.split('\t') #split on input tab
        links = eval(links) #make a dictionary
        
        if nodeID == self.options.startNode: 
            yield nodeID, (links.keys(), 0, 'Q', [nodeID]) #sets up start node
        else:
            yield nodeID, (links.keys(), maxint, 'U', [])
            
    def steps(self):
        return [MRStep(mapper = self.mapper)]

if __name__ == "__main__":
    initGraphJob.run()
# Out:
# Overwriting init_data.py

# %% [markdown]
# ##### Find Path
#
# Below is the class that finds the shortest path. It checks for nodes in the queue, and outputs them with the appropriate incremented distances. Finally, it passes all of the other nodes with corresponding statuses, and updates the queue for the next iteration.

# %%
# %%writefile shortest_path.py

from mrjob.job import MRJob
from mrjob.step import MRStep
import sys

class ShortestPathJob(MRJob):
    
    def mapper(self, _, line):
        newline = line.strip().split('\t')
        
        node = eval(newline[0])
        
        data = eval(newline[1])
        neighbors = (data[0])
        distance = int(data[1])
        label = data[2]
        path = data[3]
        
        if label == 'Q':
            for neighbor in neighbors:
                newPath = list(path)
                newPath.append(neighbor)
                yield neighbor, [None, distance + 1, 'Q', newPath]
            yield node, [neighbors, distance, 'V', path]
        else:
            yield node, [neighbors, distance, label, path]
     

    
    def reducer(self, key, values):
        #By default assume a node is unvisited with an empty list of neighbors, makes updating below easier
        neighbors = [] 
        distance = sys.maxint
        label = 'U'
        path = []
        
        for value in values:
            
            temp_neighbors = value[0]
            temp_distance = value[1]
            temp_label = value[2]
            temp_path = value[3]
            
            if temp_label == 'V':
                neighbors = temp_neighbors
                distance = temp_distance
                label = temp_label
                path = temp_path
                break
            
            elif temp_label == 'Q':
                label = temp_label
                distance = temp_distance
                path = temp_path
                
            elif temp_label == 'U':
                neighbors = temp_neighbors
                
        yield key, [neighbors, distance, label, path]
        
        
            
if __name__ == '__main__':
    ShortestPathJob.run()
# Out:
# Overwriting shortest_path.py

# %% [markdown]
# ##### Execute
#
# We run the driver code and check the output.

# %%
# !python driver.py
# Out:
# Shortest path in undirected Graph:
# No handlers could be found for logger "mrjob.runner"
# Path: [u'1', u'5', u'4'], with distance 2
# Shortest path in directed Graph:
# Path: [u'1', u'2', u'4', u'5'], with distance 3

# %% [markdown]
# -----
#
# ### Question 7.1
#
# *Using MRJob, explore the synonyms network data. Consider plotting the degree distribution (does it follow a power law?),and determine some of the key features, like:*
#
# * *number of nodes,*
# * *number links,*
# * *average degree (i.e., the average number of links per node),*
#
#
# *As you develop your code, please be sure to run it locally first (though on the whole dataset). Once you have gotten you code to run locally, deploy it on AWS as a systems test in preparation for our next dataset (which will require AWS).*
#
# #### Solution
#
# To accomplish this task, we create three jobs. The first, `number_of_nodes.py` computes the number of nodes, and `number_of_links.py` computes the total number of links. Finally, `average_degree.py` computes the average degree across the dataset. In addition, we provide a specific driver file to manage this process.
#
# ##### Driver
#
# The driver file reads in the synonym NLTK data, and runs both the node and link jobs to determine the total number of nodes and links, respectively.

# %%
# %%writefile synDriver.py

from number_of_nodes import numberOfNodes
from number_of_links import numberOfLinks
from average_degree import averageDegree

filenames = ['synNet/synNet.txt']

for filename in filenames:
    
    # Nodes 
    mr_job = numberOfNodes(args = [filename])
    print "Number of Nodes in " + filename
    with mr_job.make_runner() as runner:
        runner.run()
        for line in runner.stream_output():
            print mr_job.parse_output_line(line)
    
    # Links 
    mr_job2 = numberOfLinks(args = [filename])
    print "Number of Links in " + filename
    with mr_job2.make_runner() as runner:
        runner.run()
        for line in runner.stream_output():
            print mr_job2.parse_output_line(line)
            
    # Degree 
    mr_job3 = averageDegree(args = [filename])
    print "Average degree in " + filename
    with mr_job3.make_runner() as runner:
        runner.run()
        for line in runner.stream_output():
            print mr_job2.parse_output_line(line)
# Out:
# Writing synDriver.py

# %% [markdown]
# ##### Number of Nodes
#
# This file will compute the number of nodes. This is relatively straightforward, as we simply output the value '1' for each line in our data, which represents the listing of each node.

# %%
# %%writefile number_of_nodes.py

from mrjob.job import MRJob

class numberOfNodes(MRJob):
    
    def mapper(self, _, line):
        yield None, 1
        
    def reducer(self, _, counts): 
        yield None, sum(counts)
        
if __name__ == '__main__':
    numberOfNodes.run()
# Out:
# Writing number_of_nodes.py

# %% [markdown]
# ##### Number of Links
#
# This class will compute the number of links. This is slightly more subtle, because we may iterate over each link more than once. What we really want to count is the node pairs that are analogous with each link.

# %%
# %%writefile number_of_links.py

from mrjob.job import MRJob
from mrjob.step import MRStep 

from ast import literal_eval as load 

class numberOfLinks(MRJob):
    
    def mapper(self, _, line):
        
        # Parse 
        line = line.strip().split('\t')
        node = line[0]
        neighbors = load(line[1])
        
        for neighbor in neighbors: 
            
            # Sort 
            pair = [node, neighbor]
            pair.sort()
            
            yield pair, None
            
    
    def reducer_dedupe(self, pair, _):
        
        # Flatten 
        yield None, pair
        
        
    def reducer_agg(self, _, pairs):
        
        tally = 0
        
        # Aggregate
        for pair in pairs: 
            tally += 1 
            
        yield None, tally
    
        
    def steps(self):
        
        return [MRStep(mapper=self.mapper, 
                          reducer=self.reducer_dedupe), 
                   
                MRStep(reducer=self.reducer_agg)]
        
        
if __name__ == '__main__':
    numberOfLinks.run()
# Out:
# Writing number_of_links.py

# %% [markdown]
# ##### Average Degree
#
# Here, we implement something similar to the number of links, with the exception that our reducer will do a division aggregation instead to get an average.

# %%
# %%writefile average_degree.py 

from __future__ import division 
from mrjob.job import MRJob 

from ast import literal_eval as load 

class averageDegree(MRJob):
    
    def mapper(self, _, line): 
        
        # Parse 
        line = line.strip().split('\t')
        node = line[0]
        neighbors = load(line[1])
        
        yield None, len(neighbors)
        
    
    def reducer(self, _, lengths):
        
        tally = 0 
        count = 0
        
        # Aggregate 
        for value in lengths: 
            count += 1
            tally += value 
            
        yield None, tally / count
        
if __name__ == '__main__':
    averageDegree().run()
# Out:
# Writing average_degree.py

# %% [markdown]
# ##### Execute
#
# We now run the driver and execute our two jobs.

# %%
# !python synDriver.py
# Out:
# Number of Nodes in synNet/synNet.txt
# No handlers could be found for logger "mrjob.runner"
# (None, 8271)
# Number of Links in synNet/synNet.txt
# (None, 30567)
# Average degree in synNet/synNet.txt
# (None, 7.391367428364164)

# %% [markdown]
# ### Question 7.2
#
# *Write (reuse your code from 7.0) an MRJob class to find shortest path graph distances,
# and apply it to the NLTK synonyms network dataset.*
#
# *Proof your code's function by running the job:*
#
# - *shortest path starting at "walk" (index=7827) and ending at "make" (index=536)*
#
# *and showing you code's output. Once again, your output should include the path and the distance.*
#
# *As you develop your code, please be sure to run it locally first (though on the whole dataset).
# Once you have gotten you code to run locally, deploy it on AWS as a systems test
# in preparation for our next dataset (which will require AWS).*
#
# #### Solution
#
# Here, we re-use our code specified in Question 7.0. The only change is the driver function, which is modified to use the synonym NLTK dataset.

# %%
# %%writefile syn_path_driver.py

#Driver for iterations
import os
from init_data import initGraphJob
from shortest_path import ShortestPathJob

def findShortestPath(filename, startNode, endNode):
    
    mr_job_init = initGraphJob(args = [filename, '--startNode', startNode]) #insert text file here to change 

    with open('working-graph.txt', 'w+') as myfile:
        
        with mr_job_init.make_runner() as runner:
            runner.run()
            
            for line in runner.stream_output():
                myfile.write(line)


    while True:
        with open('newFile.txt', 'w+') as myfile:
            mr_job = ShortestPathJob(args = ['working-graph.txt'])
            
            with mr_job.make_runner() as runner:
                runner.run()
                
                for line in runner.stream_output():
                    output = mr_job.parse_output_line(line)
                    myfile.write(line)
                
                    if output[0] == endNode and output[1][2] == "V":
                        return (output[1][3], output[1][1]) 
                        break
            
        os.rename('newFile.txt', 'working-graph.txt')

print 'Shortest path in NLTK synonym data:'
results = findShortestPath('synNet/synNet.txt', '7827', '536')
print 'Path: ' + str(results[0]) + ', with distance ' + str(results[1])

# Clean 
try: 
    os.remove('newFile.txt')
    os.remove('working-graph.txt')

except: 
    print 'Unable to clean files.'
# Out:
# Overwriting syn_path_driver.py

# %%
# !python syn_path_driver.py
# Out:
# Shortest path in NLTK synonym data:
# No handlers could be found for logger "mrjob.runner"
# Path: [u'7827', u'4655', u'631', u'536'], with distance 3

# %% [markdown]
# ### Question 7.3
#
# *Using MRJob, explore the Wikipedia network data on the AWS cloud. Reuse your code from HW 7.1---does is scale well?
# Be cautioned that Wikipedia is a directed network, where links are not symmetric. So, even though a node may be linked to, it will not appear as a primary record itself if it has no out-links. This means that you may have to ADJUST your code (depending on its design). To be sure of your code's functionality in this context, run a systems test on the directed_toy.txt network.*
#
# #### Solution
#
# We utilize the data found in the S3 bucket. However, because of the `emr` tag we execute the class files directly for the three EDA procedures- number of nodes, number of links, and average degree.
#
# ##### Number of Nodes
#
# Here we count the number of nodes in the Wikipedia dataset.

# %%
# !sudo python number_of_nodes.py -r emr s3://ucb-mids-mls-networks/wikipedia/all-pages-indexed-out.txt
# Out:
# Got unexpected keyword arguments: ssh_tunnel
# no configs found; falling back on auto-configuration
# no configs found; falling back on auto-configuration
# using existing scratch bucket mrjob-01bc9d239cbfa41e
# using s3://mrjob-01bc9d239cbfa41e/tmp/ as our scratch dir on S3
# creating tmp directory /tmp/number_of_nodes.root.20160310.020003.113542
# writing master bootstrap script to /tmp/number_of_nodes.root.20160310.020003.113542/b.py
#
# PLEASE NOTE: Starting in mrjob v0.5.0, protocols will be strict by default. It's recommended you run your job with --strict-protocols or set up mrjob.conf as described at https://pythonhosted.org/mrjob/whats-new.html#ready-for-strict-protocols
#
# Copying non-input files into s3://mrjob-01bc9d239cbfa41e/tmp/number_of_nodes.root.20160310.020003.113542/files/
# Waiting 5.0s for S3 eventual consistency
# Creating Elastic MapReduce job flow
# Job flow created with ID: j-2SW79CB2KM3IY
# Created new job flow j-2SW79CB2KM3IY
# Job launched 30.6s ago, status STARTING: Provisioning Amazon EC2 capacity
# Job launched 61.3s ago, status STARTING: Provisioning Amazon EC2 capacity
# Job launched 92.0s ago, status STARTING: Provisioning Amazon EC2 capacity
# Job launched 122.8s ago, status STARTING: Provisioning Amazon EC2 capacity
# Job launched 153.5s ago, status STARTING: Provisioning Amazon EC2 capacity
# Job launched 184.5s ago, status BOOTSTRAPPING: Running bootstrap actions
# Job launched 215.2s ago, status BOOTSTRAPPING: Running bootstrap actions
# Job launched 245.9s ago, status BOOTSTRAPPING: Running bootstrap actions
# Job launched 276.7s ago, status BOOTSTRAPPING: Running bootstrap actions
# Job launched 307.5s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 338.3s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 369.0s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 399.7s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 430.4s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 461.2s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 492.3s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 523.2s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 553.8s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 584.9s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 615.6s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 646.4s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 677.6s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 708.7s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 739.4s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 770.2s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 801.1s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 832.0s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 862.7s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 893.5s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 924.3s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 955.0s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 985.8s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 1016.4s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 1047.5s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 1078.1s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 1108.8s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 1140.5s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 1171.2s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job launched 1201.9s ago, status RUNNING: Running step (number_of_nodes.root.20160310.020003.113542: Step 1 of 1)
# Job completed.
# Running time was 895.0s (not counting time spent waiting for the EC2 instances)
# ec2_key_pair_file not specified, going to S3
# Fetching counters from S3...
# Waiting 5.0s for S3 eventual consistency
# Counters from step 1:
#   File Input Format Counters :
#     Bytes Read: 2090838332
#   File Output Format Counters :
#     Bytes Written: 13
#   FileSystemCounters:
#     FILE_BYTES_READ: 2458425
#     FILE_BYTES_WRITTEN: 5791687
#     HDFS_BYTES_READ: 3680
#     S3_BYTES_READ: 2090838332
#     S3_BYTES_WRITTEN: 13
#   Job Counters :
#     Launched map tasks: 32
#     Launched reduce tasks: 1
#     Rack-local map tasks: 32
#     SLOTS_MILLIS_MAPS: 1336118
#     SLOTS_MILLIS_REDUCES: 746937
#     Total time spent by all maps waiting after reserving slots (ms): 0
#     Total time spent by all reduces waiting after reserving slots (ms): 0
#   Map-Reduce Framework:
#     CPU time spent (ms): 437790
#     Combine input records: 0
#     Combine output records: 0
#     Map input bytes: 2090459616
#     Map input records: 5781290
#     Map output bytes: 40469030
#     Map output materialized bytes: 2458870
#     Map output records: 5781290
#     Physical memory (bytes) snapshot: 8203083776
#     Reduce input groups: 1
#     Reduce input records: 5781290
#     Reduce output records: 1
#     Reduce shuffle bytes: 2458870
#     SPLIT_RAW_BYTES: 3680
#     Spilled Records: 11562580
#     Total committed heap usage (bytes): 8094482432
#     Virtual memory (bytes) snapshot: 21328953344
# Streaming final output from s3://mrjob-01bc9d239cbfa41e/tmp/number_of_nodes.root.20160310.020003.113542/output/
# null	5781290
# removing tmp directory /tmp/number_of_nodes.root.20160310.020003.113542
# Removing all files in s3://mrjob-01bc9d239cbfa41e/tmp/number_of_nodes.root.20160310.020003.113542/
# Removing all files in s3://mrjob-01bc9d239cbfa41e/tmp/logs/j-2SW79CB2KM3IY/
# Terminating job flow: j-2SW79CB2KM3IY

# %% [markdown]
# ##### Number of Links
#
# Here we count the number of links for the Wikipedia dataset.

# %%
# !sudo python number_of_links.py -r emr s3://ucb-mids-mls-networks/wikipedia/all-pages-indexed-out.txt
# Out:
# Got unexpected keyword arguments: ssh_tunnel
# no configs found; falling back on auto-configuration
# no configs found; falling back on auto-configuration
# using existing scratch bucket mrjob-01bc9d239cbfa41e
# using s3://mrjob-01bc9d239cbfa41e/tmp/ as our scratch dir on S3
# creating tmp directory /tmp/number_of_links.root.20160310.024545.134374
# writing master bootstrap script to /tmp/number_of_links.root.20160310.024545.134374/b.py
#
# PLEASE NOTE: Starting in mrjob v0.5.0, protocols will be strict by default. It's recommended you run your job with --strict-protocols or set up mrjob.conf as described at https://pythonhosted.org/mrjob/whats-new.html#ready-for-strict-protocols
#
# Copying non-input files into s3://mrjob-01bc9d239cbfa41e/tmp/number_of_links.root.20160310.024545.134374/files/
# Waiting 5.0s for S3 eventual consistency
# Creating Elastic MapReduce job flow
# Job flow created with ID: j-1R6M3KZXFLQYM
# Created new job flow j-1R6M3KZXFLQYM
# Job launched 30.6s ago, status STARTING: Provisioning Amazon EC2 capacity
# Job launched 61.2s ago, status STARTING: Provisioning Amazon EC2 capacity
# Job launched 92.0s ago, status STARTING: Provisioning Amazon EC2 capacity
# Job launched 122.6s ago, status STARTING: Provisioning Amazon EC2 capacity
# Job launched 153.6s ago, status STARTING: Provisioning Amazon EC2 capacity
# Job launched 184.2s ago, status STARTING: Provisioning Amazon EC2 capacity
# Job launched 214.9s ago, status STARTING: Provisioning Amazon EC2 capacity
# Job launched 245.5s ago, status BOOTSTRAPPING: Running bootstrap actions
# Job launched 276.2s ago, status BOOTSTRAPPING: Running bootstrap actions
# Job launched 306.9s ago, status BOOTSTRAPPING: Running bootstrap actions
# Job launched 337.5s ago, status BOOTSTRAPPING: Running bootstrap actions
# Job launched 368.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 398.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 429.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 460.0s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 490.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 521.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 552.2s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 582.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 613.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 644.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 674.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 705.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 735.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 766.5s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 797.0s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 827.6s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 858.2s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 888.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 919.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 950.0s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 980.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1011.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1042.0s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1072.6s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1103.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1134.2s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1164.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1195.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1230.5s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1261.2s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1291.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1322.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1353.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1383.6s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1414.2s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1444.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1475.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1505.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1536.5s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1567.2s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1597.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1628.5s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1659.0s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1689.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1720.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1751.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1782.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1812.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1843.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1874.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1904.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1935.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1966.0s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 1996.5s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2027.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2057.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2088.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2119.0s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2149.6s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2180.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2210.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2241.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2271.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2302.5s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2333.2s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2363.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2394.5s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2429.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2460.6s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2491.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2521.6s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2552.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2583.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2613.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2644.5s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2675.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2705.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2736.2s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2766.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2797.6s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2828.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2858.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2889.6s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2920.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2950.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 2981.5s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3012.0s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3042.6s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3073.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3103.6s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3134.2s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3164.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3195.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3226.0s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3256.6s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3292.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3322.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3353.5s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3390.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3421.0s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3451.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3482.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3513.5s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3544.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3575.0s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3605.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3636.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3667.2s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3697.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3728.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3759.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3789.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3820.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3851.0s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3881.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3912.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3943.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 3973.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4004.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4035.0s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4065.6s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4096.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4126.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4157.6s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4188.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4219.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4249.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4280.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4311.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4341.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4372.6s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4403.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4434.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4470.5s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4501.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4531.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4562.5s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4593.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4624.0s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4654.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4685.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4716.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4747.2s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4777.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4808.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4839.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4869.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4900.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4931.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4961.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 4992.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5023.0s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5053.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5084.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5114.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5145.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5176.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5206.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5237.6s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5268.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5299.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5329.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5360.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5391.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5421.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5452.6s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5483.2s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5513.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5550.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5580.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5611.6s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5642.2s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5673.2s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5704.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5734.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5765.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5795.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5826.6s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5857.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5888.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5918.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5949.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 5980.2s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6010.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6041.5s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6072.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6103.0s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6133.6s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6164.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6195.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6225.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6256.5s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6287.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6317.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6348.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6379.0s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6409.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6440.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6470.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6501.5s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6532.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6562.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6593.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6629.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6660.6s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6691.2s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6721.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6752.5s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6783.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6813.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6844.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6875.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6905.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6936.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6966.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 6997.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7028.6s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7059.2s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7089.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7120.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7151.0s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7181.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7212.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7242.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7273.5s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7304.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7334.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7365.5s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7396.2s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7426.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7457.6s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7488.2s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7519.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7549.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7580.5s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7611.2s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7641.8s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7672.4s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7703.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7733.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7764.5s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7795.0s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7830.5s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7861.1s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7891.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7922.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7953.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 7983.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 8014.5s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 8045.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 8076.0s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 8106.7s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 8137.3s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# Job launched 8167.9s ago, status RUNNING: Running step (number_of_links.root.20160310.024545.134374: Step 1 of 2)
# ^C

# %% [markdown]
# ### Question 7.4
#
# *Using MRJob, find shortest path graph distances in the Wikipedia network on the AWS cloud.
# Reuse your code from 7.2, but once again be warned of Wikipedia being a directed network.
# To be sure of your code's functionality in this context, run a systems test on the directed_toy.txt network.*
#
# *When running your code on the Wikipedia network, proof its function by running the job:*
#
# - *shortest path from "Ireland" (index=6176135) to "University of California, Berkeley" (index=13466359),*
#
# *and show your code's output. Show the shortest path in terms of just page IDS but also in terms of the name of page (show of your MapReduce join skills!!)*
#
# *Once your code is running, find some other shortest paths and report your results.*

# %% [markdown]
# ### Question 7.5
#
# *Suppose you wanted to find the largest network distance from a single source,
# i.e., a node that is the furthest (but still reachable) from a single source.*
#
# *How would you implement this task?
# How is this different from finding the shortest path graph distances?*
#
# *Is this task more difficult to implement than the shortest path distance?*
#
# *As you respond, please comment on program structure, runtimes, iterations, general system requirements, etc...*
#
# #### Solution
#
# This would be the safe difficulty as finding the shortest path (within MRJob). The argument for this is that to find the shortest path from a starting node to an arbitrary node, I have to compute the distance for all other nodes in the graph. In other words, the distance calculation is identical between the two. The difference between the longest and shortest distance implementation is how the stream is parsed. For the former, I look at the largest value in the set, and for the latter the smallest.

# %% [markdown]
# ### Question 7.6 (Optional)
#
# *Using MRJob, write a code to find the largest graph distance and distance-maximizing nodes from a single-source.
# Test your code first on the toy networks and synonyms network to proof its function.*
#
# #### Solution
#
# We re-use our `shortest_path` implementation, but we modify the driver to return the maximal element rather than the end-node that is specified.
